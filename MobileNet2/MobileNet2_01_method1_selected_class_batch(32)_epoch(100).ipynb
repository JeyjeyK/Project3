# %% [markdown]
# https://www.kaggle.com/code/imsparsh/food-classifier-mobilenetv2-resnet50-vgg16

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import random

import tensorflow as tf
from tensorflow.keras import layers as k
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, classification_report

import json
import pickle
from tqdm import tqdm

import cv2
from google.colab.patches import cv2_imshow

import os
import warnings
warnings.filterwarnings('ignore')

import gc

seed = 42

# %%
image_size = (224, 224, 3)
batch_num = 32
epoch_num = 100

# create_model_name
model = 'MobileNet2'
numbering = '01'
preprocessing_method ='method1'
class_type = 'selected_class'

# 고정 내역
max_pic_cnt = 1000
top_layer = 'customized_top_layer'

model_name = f'{model}_{numbering}_{preprocessing_method}_{class_type}_batch({batch_num})_epoch({epoch_num})'
print(model_name)
# Out:
# MobileNet2_01_method1_selected_class_batch(32)_epoch(100)

# %%
# create model folder
base_path = f'/content/drive/MyDrive/project3/image_model/{model}'
if not os.path.exists(base_path):
    os.makedirs(base_path)

model_path = f'/content/drive/MyDrive/project3/image_model/{model}/{model_name}'
if not os.path.exists(model_path):
    os.makedirs(model_path)

# result folder
result_path = f'/content/drive/MyDrive/project3/image_model/{model}/{model_name}/result'
if not os.path.exists(result_path):
    os.makedirs(result_path)

# %% [markdown]
# ### data 준비

# %%
def get_image():
    pkl_dir_path = f'/content/drive/MyDrive/project3/data/traindata/image_to_list/{class_type}_square/{preprocessing_method}.pkl'
    df = pd.read_pickle(pkl_dir_path)

    image_list = np.array([x.reshape(224, 224, 3) for x in df['sq_list']])
    target_list = df['small_class']

    image_list = np.array(image_list).astype(np.uint8)
    target_list = np.array(target_list)

    return image_list, target_list


def prepare_data(test_size=0.2, random_state=42):
    # get_image 함수를 통해서 image / target 가져오기
    image_list, target_list = get_image()

    label_encoder = LabelEncoder()
    encoded_target_list = label_encoder.fit_transform(target_list)

    # Train-Test Split
    X_train, X_test, y_train, y_test = train_test_split(image_list, encoded_target_list, test_size=test_size, random_state=random_state)

    # image_array 정규화
    X_train = X_train / 255.0
    X_test = X_test / 255.0

    num_classes = len(np.unique(target_list))

    # target (one-hot encoding)
    y_train = to_categorical(y_train, num_classes)
    y_test = to_categorical(y_test, num_classes)

    return X_train, X_test, y_train, y_test, target_list, label_encoder

# 나중에 다시 label을 출력하기 위한 코드
def decode_labels(encoded_label, label_encoder):
    return label_encoder.inverse_transform(encoded_label)

# %%
X_train, X_test, y_train, y_test, target_list, label_encoder = prepare_data()
num_classes = len(np.unique(target_list))

print(f"X_train : {X_train.shape}")
print(f"X_test : {X_test.shape}")
print(f"y_train : {y_train.shape}")
print(f"y_test : {y_test.shape}")
print(f'Target count: {num_classes}')
# Out:
# X_train : (21876, 224, 224, 3)
# X_test : (5469, 224, 224, 3)
# y_train : (21876, 38)
# y_test : (5469, 38)
# Target count: 38

# %%
pic_num = 900
decoded_label = decode_labels([np.argmax(y_train[pic_num])], label_encoder)
print(f"Label: {decoded_label[0]}")
print(X_train[pic_num].shape)
cv2_imshow(X_train[pic_num] * 255)
# Out:
# Label: 육개장
# (224, 224, 3)
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# ### 모델 설계

# %%
# Load the MobileNetV2
# model pre-trained -> by imagenet dataset
# without the top layer -> 마지막 결과를 내는 레이어 층에 관한
mobilenet = MobileNetV2(weights='imagenet', input_shape=[224,224,3], include_top=False)
mobilenet.trainable = False

model = tf.keras.models.Sequential([
                             mobilenet,
                             tf.keras.layers.GlobalAveragePooling2D(),
                             k.Dropout(0.2),
                             k.Dense(256, activation='relu'),
                             k.BatchNormalization(),
                             k.Dropout(0.1),
                             k.Dense(128, activation='relu'),
                             k.BatchNormalization(),
                             k.Dropout(0.1),
                             k.Dense(num_classes, activation='softmax')
])
print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 2s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  global_average_pooling2d (  (None, 1280)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 256)               327936
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_1 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 38)                4902
#
# =================================================================
# Total params: 2625254 (10.01 MB)
# Trainable params: 366502 (1.40 MB)
# Non-trainable params: 2258752 (8.62 MB)
# _________________________________________________________________
# None

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint(filepath=os.path.join(model_path, f'{model_name}_best.h5'),
                                   monitor='val_loss', save_best_only=True)


model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=[tf.keras.metrics.CategoricalAccuracy(), tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')]
)

history = model.fit(X_train, y_train, epochs= epoch_num, batch_size= batch_num, validation_split= 0.15,
                    callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/100
# 582/582 [==============================] - 25s 30ms/step - loss: 1.6704 - categorical_accuracy: 0.5332 - precision: 0.7867 - recall: 0.3537 - val_loss: 1.0125 - val_categorical_accuracy: 0.7038 - val_precision: 0.8456 - val_recall: 0.5874
# Epoch 2/100
# 582/582 [==============================] - 12s 21ms/step - loss: 1.1060 - categorical_accuracy: 0.6736 - precision: 0.8149 - recall: 0.5527 - val_loss: 0.9458 - val_categorical_accuracy: 0.7307 - val_precision: 0.8402 - val_recall: 0.6408
# Epoch 3/100
# 582/582 [==============================] - 13s 23ms/step - loss: 0.9640 - categorical_accuracy: 0.7090 - precision: 0.8285 - recall: 0.6089 - val_loss: 0.8641 - val_categorical_accuracy: 0.7447 - val_precision: 0.8435 - val_recall: 0.6618
# Epoch 4/100
# 582/582 [==============================] - 12s 21ms/step - loss: 0.8762 - categorical_accuracy: 0.7324 - precision: 0.8330 - recall: 0.6441 - val_loss: 0.8546 - val_categorical_accuracy: 0.7498 - val_precision: 0.8358 - val_recall: 0.6761
# Epoch 5/100
# 582/582 [==============================] - 13s 22ms/step - loss: 0.8181 - categorical_accuracy: 0.7450 - precision: 0.8400 - recall: 0.6652 - val_loss: 0.8465 - val_categorical_accuracy: 0.7508 - val_precision: 0.8340 - val_recall: 0.6813
# Epoch 6/100
# 582/582 [==============================] - 12s 20ms/step - loss: 0.7831 - categorical_accuracy: 0.7563 - precision: 0.8418 - recall: 0.6832 - val_loss: 0.8562 - val_categorical_accuracy: 0.7456 - val_precision: 0.8281 - val_recall: 0.6886
# Epoch 7/100
# 582/582 [==============================] - 12s 20ms/step - loss: 0.7472 - categorical_accuracy: 0.7661 - precision: 0.8471 - recall: 0.6951 - val_loss: 0.8631 - val_categorical_accuracy: 0.7407 - val_precision: 0.8229 - val_recall: 0.6895
# Epoch 8/100
# 582/582 [==============================] - 13s 22ms/step - loss: 0.7119 - categorical_accuracy: 0.7745 - precision: 0.8548 - recall: 0.7058 - val_loss: 0.8285 - val_categorical_accuracy: 0.7550 - val_precision: 0.8234 - val_recall: 0.6974
# Epoch 9/100
# 582/582 [==============================] - 12s 20ms/step - loss: 0.6731 - categorical_accuracy: 0.7837 - precision: 0.8561 - recall: 0.7244 - val_loss: 0.8135 - val_categorical_accuracy: 0.7660 - val_precision: 0.8306 - val_recall: 0.7169
# Epoch 10/100
# 582/582 [==============================] - 11s 20ms/step - loss: 0.6422 - categorical_accuracy: 0.7984 - precision: 0.8653 - recall: 0.7363 - val_loss: 0.8426 - val_categorical_accuracy: 0.7508 - val_precision: 0.8252 - val_recall: 0.7063
# Epoch 11/100
# 582/582 [==============================] - 11s 20ms/step - loss: 0.6250 - categorical_accuracy: 0.8015 - precision: 0.8654 - recall: 0.7444 - val_loss: 0.8507 - val_categorical_accuracy: 0.7633 - val_precision: 0.8219 - val_recall: 0.7197
# Epoch 12/100
# 582/582 [==============================] - 12s 20ms/step - loss: 0.6104 - categorical_accuracy: 0.8038 - precision: 0.8679 - recall: 0.7504 - val_loss: 0.8438 - val_categorical_accuracy: 0.7648 - val_precision: 0.8227 - val_recall: 0.7267
# Epoch 13/100
# 582/582 [==============================] - 11s 20ms/step - loss: 0.5952 - categorical_accuracy: 0.8064 - precision: 0.8671 - recall: 0.7565 - val_loss: 0.8304 - val_categorical_accuracy: 0.7724 - val_precision: 0.8306 - val_recall: 0.7337
# Epoch 14/100
# 582/582 [==============================] - 11s 20ms/step - loss: 0.5620 - categorical_accuracy: 0.8177 - precision: 0.8736 - recall: 0.7675 - val_loss: 0.8191 - val_categorical_accuracy: 0.7639 - val_precision: 0.8225 - val_recall: 0.7273
# Epoch 15/100
# 582/582 [==============================] - 12s 20ms/step - loss: 0.5527 - categorical_accuracy: 0.8189 - precision: 0.8754 - recall: 0.7741 - val_loss: 0.8465 - val_categorical_accuracy: 0.7547 - val_precision: 0.8157 - val_recall: 0.7160
# Epoch 16/100
# 582/582 [==============================] - 11s 20ms/step - loss: 0.5462 - categorical_accuracy: 0.8216 - precision: 0.8736 - recall: 0.7787 - val_loss: 0.8627 - val_categorical_accuracy: 0.7550 - val_precision: 0.8091 - val_recall: 0.7230
# Epoch 17/100
# 582/582 [==============================] - 12s 20ms/step - loss: 0.5307 - categorical_accuracy: 0.8267 - precision: 0.8771 - recall: 0.7822 - val_loss: 0.8529 - val_categorical_accuracy: 0.7578 - val_precision: 0.8091 - val_recall: 0.7206
# Epoch 18/100
# 582/582 [==============================] - 12s 20ms/step - loss: 0.4999 - categorical_accuracy: 0.8356 - precision: 0.8846 - recall: 0.7927 - val_loss: 0.8525 - val_categorical_accuracy: 0.7657 - val_precision: 0.8120 - val_recall: 0.7343
# Epoch 19/100
# 582/582 [==============================] - 12s 20ms/step - loss: 0.4827 - categorical_accuracy: 0.8380 - precision: 0.8851 - recall: 0.8010 - val_loss: 0.8631 - val_categorical_accuracy: 0.7636 - val_precision: 0.8162 - val_recall: 0.7291

# %%
# model save
model.save(os.path.join(model_path, f'{model_name}.h5'))


# training history save
with open(os.path.join(result_path, f'{model_name}_history.json'), 'w') as f:
    json.dump(history.history, f)

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['categorical_accuracy'], label='Train Accuracy')
plt.plot(history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy By Epochs')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss By Epochs')

plt.suptitle(f'{model_name}')

# save training_plot
plt.savefig(os.path.join(result_path, f'{model_name}_training_plot.png'))
plt.show()

# %%
y_pred = model.predict(X_test)

# Convert one-hot encoded predictions and actual values to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# Print classification report for detailed metrics
class_report = classification_report(y_true_classes, y_pred_classes)
print(class_report)

with open(os.path.join(result_path, f'{model_name}_classification_report.txt'), 'w') as f:
    f.write(class_report)

# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title(f'{model_name}_Confusion Matrix')

plt.savefig(os.path.join(result_path, f'{model_name}_confusion_matrix.png'))
plt.show()
# Out:
# 171/171 [==============================] - 3s 13ms/step
#               precision    recall  f1-score   support
#
#            0       0.68      0.76      0.72       135
#            1       0.64      0.67      0.66       129
#            2       0.73      0.77      0.75       169
#            3       0.55      0.54      0.55       125
#            4       0.86      0.82      0.84       180
#            5       0.80      0.88      0.84       140
#            6       0.87      0.79      0.82       131
#            7       0.90      0.82      0.86       128
#            8       0.75      0.78      0.76       148
#            9       0.76      0.76      0.76       147
#           10       0.53      0.58      0.55       159
#           11       0.91      0.77      0.83       139
#           12       0.77      0.91      0.83       157
#           13       0.77      0.74      0.76       157
#           14       0.63      0.60      0.62       141
#           15       0.66      0.72      0.69       164
#           16       0.84      0.81      0.82       118
#           17       0.61      0.49      0.55       138
#           18       0.76      0.79      0.77       158
#           19       0.64      0.57      0.60       140
#           20       0.86      0.76      0.80       149
#           21       0.65      0.70      0.67       159
#           22       0.95      0.92      0.94       143
#           23       0.84      0.46      0.59       149
#           24       0.56      0.62      0.59       143
#           25       0.85      0.92      0.89       167
#           26       0.71      0.74      0.72       148
#           27       0.75      0.79      0.77       149
#           28       0.78      0.83      0.80       147
#           29       0.83      0.80      0.82       137
#           30       0.82      0.69      0.75       121
#           31       0.76      0.66      0.71       147
#           32       0.75      0.56      0.64       163
#           33       0.72      0.87      0.79       136
#           34       0.74      0.88      0.80       131
#           35       0.71      0.84      0.77       134
#           36       0.87      0.80      0.83       112
#           37       0.68      0.89      0.77       131
#
#     accuracy                           0.74      5469
#    macro avg       0.75      0.74      0.74      5469
# weighted avg       0.75      0.74      0.74      5469

# %%
y_pred_classes
# Out:
# array([26, 30, 21, ..., 29, 24, 21])

# %%
y_true_classes
# Out:
# array([26, 30, 21, ..., 29, 24, 27])

# %%
# Calculate accuracy using sklearn
accuracy = accuracy_score(y_true_classes, y_pred_classes)
print('Accuracy:', accuracy)

# Calculate precision and recall using sklearn
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
print('Precision:', precision)
print('Recall:', recall)

# Append accuracy to a text file
with open(os.path.join(base_path, 'accuracy.txt'), 'a') as f:
    f.write(f'{model_name}_Accuracy: {accuracy:.2f}%\n')
    f.write(f'{model_name}_Precision: {precision:.2f}%\n')
    f.write(f'{model_name}_Recall: {recall:.2f}%\n')
# Out:
# Accuracy: 0.7441945511062351
# Precision: 0.7486993163148484
# Recall: 0.7441945511062351

# %%
# cnt = 0
# for i in range(len(y_pred_classes)):
#     print('예측 : ', y_pred_classes[i], "실제 :", y_true_classes[i])
#     if y_pred_classes[i] == y_true_classes[i]:
#         cnt += 1
# print('정확도', cnt / len(y_pred_classes) * 100, '%')

# with open(os.path.join(model_path, 'accuracy.txt'), 'w') as f:
#     f.write(f'{model}_Accuracy: {cnt / len(y_pred_classes) * 100:.2f}%\n')
