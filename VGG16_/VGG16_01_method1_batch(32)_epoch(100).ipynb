# %% [markdown]
# https://www.kaggle.com/code/imsparsh/food-classifier-mobilenetv2-resnet50-vgg16

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import random

import tensorflow as tf
from tensorflow.keras import layers as k
from tensorflow.keras.applications import VGG16
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, classification_report

import json
import pickle
from tqdm import tqdm

import cv2
from google.colab.patches import cv2_imshow

import os
import warnings
warnings.filterwarnings('ignore')

import gc

seed = 42

# %%
image_size = (224, 224, 3)
batch_num = 32
epoch_num = 100

# create_model_name
model = 'VGG16'
numbering = '01'
preprocessing_method ='method1'
class_type = 'selected_class'

# 고정 내역
max_pic_cnt = 1000
top_layer = 'customized_top_layer'

model_name = f'{model}_{numbering}_{preprocessing_method}_{class_type}_batch({batch_num})_epoch({epoch_num})'
print(model_name)
# Out:
# VGG16_01_method1_selected_class_batch(32)_epoch(100)

# %%
# create model folder
base_path = f'/content/drive/MyDrive/project3/image_model/{model}'
if not os.path.exists(base_path):
    os.makedirs(base_path)

model_path = f'/content/drive/MyDrive/project3/image_model/{model}/{model_name}'
if not os.path.exists(model_path):
    os.makedirs(model_path)

# result folder
result_path = f'/content/drive/MyDrive/project3/image_model/{model}/{model_name}/result'
if not os.path.exists(result_path):
    os.makedirs(result_path)

# %% [markdown]
# ### data 준비

# %%
def get_image():
    pkl_dir_path = f'/content/drive/MyDrive/project3/data/traindata/image_to_list/{class_type}_square/{preprocessing_method}.pkl'
    df = pd.read_pickle(pkl_dir_path)

    image_list = np.array([x.reshape(224, 224, 3) for x in df['sq_list']])
    target_list = df['small_class']

    image_list = np.array(image_list).astype(np.uint8)
    target_list = np.array(target_list)

    return image_list, target_list


def prepare_data(test_size=0.2, random_state=42):
    # get_image 함수를 통해서 image / target 가져오기
    image_list, target_list = get_image()

    label_encoder = LabelEncoder()
    encoded_target_list = label_encoder.fit_transform(target_list)

    # Train-Test Split
    X_train, X_test, y_train, y_test = train_test_split(image_list, encoded_target_list, test_size=test_size, random_state=random_state)

    # image_array 정규화
    X_train = X_train / 255.0
    X_test = X_test / 255.0

    num_classes = len(np.unique(target_list))

    # target (one-hot encoding)
    y_train = to_categorical(y_train, num_classes)
    y_test = to_categorical(y_test, num_classes)

    return X_train, X_test, y_train, y_test, target_list, label_encoder

# 나중에 다시 label을 출력하기 위한 코드
def decode_labels(encoded_label, label_encoder):
    return label_encoder.inverse_transform(encoded_label)

# %%
X_train, X_test, y_train, y_test, target_list, label_encoder = prepare_data()
num_classes = len(np.unique(target_list))

print(f"X_train : {X_train.shape}")
print(f"X_test : {X_test.shape}")
print(f"y_train : {y_train.shape}")
print(f"y_test : {y_test.shape}")
print(f'Target count: {num_classes}')
# Out:
# X_train : (21876, 224, 224, 3)
# X_test : (5469, 224, 224, 3)
# y_train : (21876, 38)
# y_test : (5469, 38)
# Target count: 38

# %%
pic_num = 900
decoded_label = decode_labels([np.argmax(y_train[pic_num])], label_encoder)
print(f"Label: {decoded_label[0]}")
print(X_train[pic_num].shape)
cv2_imshow(X_train[pic_num] * 255)
# Out:
# Label: 육개장
# (224, 224, 3)
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# ### 모델 설계

# %%
# Load the VGG16
# model pre-trained -> by imagenet dataset
# without the top layer -> 마지막 결과를 내는 레이어 층에 관한
vgg16 = VGG16(weights='imagenet', input_shape=[224, 224, 3], include_top=False)
vgg16.trainable = False  # Freeze the layers of VGG16

# Define the Customized top layer
model = tf.keras.models.Sequential([
    vgg16,
    tf.keras.layers.GlobalAveragePooling2D(),
    k.Dropout(0.2),
    k.Dense(512, activation='relu'),
    k.BatchNormalization(),
    k.Dropout(0.1),
    k.Dense(256, activation='relu'),
    k.BatchNormalization(),
    k.Dropout(0.1),
    k.Dense(num_classes, activation='softmax')
])

print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 38)                9766
#
# =================================================================
# Total params: 15121510 (57.68 MB)
# Trainable params: 405286 (1.55 MB)
# Non-trainable params: 14716224 (56.14 MB)
# _________________________________________________________________
# None

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint(filepath=os.path.join(model_path, f'{model_name}_best.h5'),
                                   monitor='val_loss', save_best_only=True)


model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=[tf.keras.metrics.CategoricalAccuracy(), tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')]
)

history = model.fit(X_train, y_train, epochs= epoch_num, batch_size= batch_num, validation_split= 0.15,
                    callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/100
# 582/582 [==============================] - 35s 48ms/step - loss: 2.1425 - categorical_accuracy: 0.4010 - precision: 0.6863 - recall: 0.2271 - val_loss: 1.2636 - val_categorical_accuracy: 0.6338 - val_precision: 0.8117 - val_recall: 0.4558
# Epoch 2/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.5659 - categorical_accuracy: 0.5364 - precision: 0.7253 - recall: 0.3889 - val_loss: 1.1427 - val_categorical_accuracy: 0.6597 - val_precision: 0.8167 - val_recall: 0.5186
# Epoch 3/100
# 582/582 [==============================] - 19s 32ms/step - loss: 1.4261 - categorical_accuracy: 0.5756 - precision: 0.7437 - recall: 0.4353 - val_loss: 1.0865 - val_categorical_accuracy: 0.6728 - val_precision: 0.8252 - val_recall: 0.5308
# Epoch 4/100
# 582/582 [==============================] - 18s 32ms/step - loss: 1.3440 - categorical_accuracy: 0.5957 - precision: 0.7602 - recall: 0.4577 - val_loss: 1.0217 - val_categorical_accuracy: 0.6871 - val_precision: 0.8414 - val_recall: 0.5753
# Epoch 5/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.2922 - categorical_accuracy: 0.6050 - precision: 0.7668 - recall: 0.4759 - val_loss: 1.0361 - val_categorical_accuracy: 0.6889 - val_precision: 0.8311 - val_recall: 0.5683
# Epoch 6/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.2630 - categorical_accuracy: 0.6179 - precision: 0.7729 - recall: 0.4878 - val_loss: 1.0046 - val_categorical_accuracy: 0.6935 - val_precision: 0.8279 - val_recall: 0.5716
# Epoch 7/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.2257 - categorical_accuracy: 0.6282 - precision: 0.7840 - recall: 0.4998 - val_loss: 1.0182 - val_categorical_accuracy: 0.6880 - val_precision: 0.8408 - val_recall: 0.5713
# Epoch 8/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.2031 - categorical_accuracy: 0.6309 - precision: 0.7806 - recall: 0.5089 - val_loss: 0.9803 - val_categorical_accuracy: 0.7069 - val_precision: 0.8410 - val_recall: 0.5932
# Epoch 9/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.1804 - categorical_accuracy: 0.6373 - precision: 0.7851 - recall: 0.5205 - val_loss: 0.9584 - val_categorical_accuracy: 0.7105 - val_precision: 0.8329 - val_recall: 0.6045
# Epoch 10/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.1638 - categorical_accuracy: 0.6440 - precision: 0.7873 - recall: 0.5227 - val_loss: 0.9398 - val_categorical_accuracy: 0.7160 - val_precision: 0.8360 - val_recall: 0.6149
# Epoch 11/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.1413 - categorical_accuracy: 0.6476 - precision: 0.7848 - recall: 0.5310 - val_loss: 0.9729 - val_categorical_accuracy: 0.7096 - val_precision: 0.8267 - val_recall: 0.6106
# Epoch 12/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.1330 - categorical_accuracy: 0.6519 - precision: 0.7916 - recall: 0.5367 - val_loss: 0.9187 - val_categorical_accuracy: 0.7246 - val_precision: 0.8479 - val_recall: 0.6130
# Epoch 13/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.1085 - categorical_accuracy: 0.6603 - precision: 0.7951 - recall: 0.5473 - val_loss: 0.9393 - val_categorical_accuracy: 0.7133 - val_precision: 0.8273 - val_recall: 0.6130
# Epoch 14/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0924 - categorical_accuracy: 0.6643 - precision: 0.7956 - recall: 0.5526 - val_loss: 0.9054 - val_categorical_accuracy: 0.7200 - val_precision: 0.8490 - val_recall: 0.6167
# Epoch 15/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0829 - categorical_accuracy: 0.6642 - precision: 0.7983 - recall: 0.5536 - val_loss: 0.9147 - val_categorical_accuracy: 0.7215 - val_precision: 0.8258 - val_recall: 0.6152
# Epoch 16/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0730 - categorical_accuracy: 0.6698 - precision: 0.7965 - recall: 0.5614 - val_loss: 0.9289 - val_categorical_accuracy: 0.7203 - val_precision: 0.8335 - val_recall: 0.6286
# Epoch 17/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0783 - categorical_accuracy: 0.6666 - precision: 0.7945 - recall: 0.5567 - val_loss: 0.9263 - val_categorical_accuracy: 0.7169 - val_precision: 0.8316 - val_recall: 0.6200
# Epoch 18/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0677 - categorical_accuracy: 0.6658 - precision: 0.7912 - recall: 0.5616 - val_loss: 0.9115 - val_categorical_accuracy: 0.7294 - val_precision: 0.8495 - val_recall: 0.6258
# Epoch 19/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0459 - categorical_accuracy: 0.6801 - precision: 0.8001 - recall: 0.5744 - val_loss: 0.9161 - val_categorical_accuracy: 0.7252 - val_precision: 0.8350 - val_recall: 0.6383
# Epoch 20/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0498 - categorical_accuracy: 0.6747 - precision: 0.8039 - recall: 0.5718 - val_loss: 0.8911 - val_categorical_accuracy: 0.7279 - val_precision: 0.8399 - val_recall: 0.6268
# Epoch 21/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0258 - categorical_accuracy: 0.6812 - precision: 0.8037 - recall: 0.5786 - val_loss: 0.8710 - val_categorical_accuracy: 0.7392 - val_precision: 0.8433 - val_recall: 0.6493
# Epoch 22/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0229 - categorical_accuracy: 0.6770 - precision: 0.7984 - recall: 0.5768 - val_loss: 0.8919 - val_categorical_accuracy: 0.7325 - val_precision: 0.8421 - val_recall: 0.6386
# Epoch 23/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0192 - categorical_accuracy: 0.6833 - precision: 0.8037 - recall: 0.5835 - val_loss: 0.8832 - val_categorical_accuracy: 0.7340 - val_precision: 0.8343 - val_recall: 0.6456
# Epoch 24/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0070 - categorical_accuracy: 0.6870 - precision: 0.8080 - recall: 0.5854 - val_loss: 0.8854 - val_categorical_accuracy: 0.7361 - val_precision: 0.8417 - val_recall: 0.6432
# Epoch 25/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0015 - categorical_accuracy: 0.6883 - precision: 0.8053 - recall: 0.5887 - val_loss: 0.8813 - val_categorical_accuracy: 0.7316 - val_precision: 0.8489 - val_recall: 0.6368
# Epoch 26/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9901 - categorical_accuracy: 0.6917 - precision: 0.8103 - recall: 0.5935 - val_loss: 0.8896 - val_categorical_accuracy: 0.7343 - val_precision: 0.8413 - val_recall: 0.6459
# Epoch 27/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9856 - categorical_accuracy: 0.6926 - precision: 0.8055 - recall: 0.5959 - val_loss: 0.8765 - val_categorical_accuracy: 0.7383 - val_precision: 0.8456 - val_recall: 0.6493
# Epoch 28/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9809 - categorical_accuracy: 0.6948 - precision: 0.8100 - recall: 0.5985 - val_loss: 0.9003 - val_categorical_accuracy: 0.7209 - val_precision: 0.8315 - val_recall: 0.6450
# Epoch 29/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.9556 - categorical_accuracy: 0.6989 - precision: 0.8128 - recall: 0.6039 - val_loss: 0.8557 - val_categorical_accuracy: 0.7428 - val_precision: 0.8444 - val_recall: 0.6645
# Epoch 30/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9590 - categorical_accuracy: 0.6996 - precision: 0.8140 - recall: 0.6066 - val_loss: 0.8660 - val_categorical_accuracy: 0.7422 - val_precision: 0.8479 - val_recall: 0.6539
# Epoch 31/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9624 - categorical_accuracy: 0.6983 - precision: 0.8090 - recall: 0.6055 - val_loss: 0.8739 - val_categorical_accuracy: 0.7367 - val_precision: 0.8422 - val_recall: 0.6520
# Epoch 32/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9434 - categorical_accuracy: 0.7050 - precision: 0.8128 - recall: 0.6075 - val_loss: 0.8636 - val_categorical_accuracy: 0.7392 - val_precision: 0.8439 - val_recall: 0.6639
# Epoch 33/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9576 - categorical_accuracy: 0.7003 - precision: 0.8092 - recall: 0.6101 - val_loss: 0.8748 - val_categorical_accuracy: 0.7386 - val_precision: 0.8367 - val_recall: 0.6481
# Epoch 34/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9389 - categorical_accuracy: 0.7061 - precision: 0.8153 - recall: 0.6140 - val_loss: 0.8656 - val_categorical_accuracy: 0.7419 - val_precision: 0.8358 - val_recall: 0.6624
# Epoch 35/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9333 - categorical_accuracy: 0.7072 - precision: 0.8184 - recall: 0.6179 - val_loss: 0.8996 - val_categorical_accuracy: 0.7288 - val_precision: 0.8288 - val_recall: 0.6429
# Epoch 36/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9224 - categorical_accuracy: 0.7081 - precision: 0.8166 - recall: 0.6150 - val_loss: 0.8621 - val_categorical_accuracy: 0.7343 - val_precision: 0.8273 - val_recall: 0.6600
# Epoch 37/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9316 - categorical_accuracy: 0.7046 - precision: 0.8082 - recall: 0.6131 - val_loss: 0.8815 - val_categorical_accuracy: 0.7352 - val_precision: 0.8329 - val_recall: 0.6548
# Epoch 38/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9151 - categorical_accuracy: 0.7113 - precision: 0.8225 - recall: 0.6224 - val_loss: 0.8703 - val_categorical_accuracy: 0.7343 - val_precision: 0.8333 - val_recall: 0.6578
# Epoch 39/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9126 - categorical_accuracy: 0.7146 - precision: 0.8178 - recall: 0.6283 - val_loss: 0.8871 - val_categorical_accuracy: 0.7270 - val_precision: 0.8212 - val_recall: 0.6548

# %%
# model save
model.save(os.path.join(model_path, f'{model_name}.h5'))


# training history save
with open(os.path.join(result_path, f'{model_name}_history.json'), 'w') as f:
    json.dump(history.history, f)

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['categorical_accuracy'], label='Train Accuracy')
plt.plot(history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy By Epochs')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss By Epochs')

plt.suptitle(f'{model_name}')

# save training_plot
plt.savefig(os.path.join(result_path, f'{model_name}_training_plot.png'))
plt.show()

# %%
y_pred = model.predict(X_test)

# Convert one-hot encoded predictions and actual values to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# Print classification report for detailed metrics
class_report = classification_report(y_true_classes, y_pred_classes)
print(class_report)

with open(os.path.join(result_path, f'{model_name}_classification_report.txt'), 'w') as f:
    f.write(class_report)

# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title(f'{model_name}_Confusion Matrix')

plt.savefig(os.path.join(result_path, f'{model_name}_confusion_matrix.png'))
plt.show()
# Out:
# 171/171 [==============================] - 4s 21ms/step
#               precision    recall  f1-score   support
#
#            0       0.69      0.79      0.74       135
#            1       0.58      0.41      0.48       129
#            2       0.71      0.70      0.70       169
#            3       0.69      0.42      0.52       125
#            4       0.91      0.80      0.85       180
#            5       0.86      0.92      0.89       140
#            6       0.77      0.76      0.77       131
#            7       0.84      0.88      0.86       128
#            8       0.71      0.78      0.74       148
#            9       0.87      0.67      0.76       147
#           10       0.58      0.58      0.58       159
#           11       0.87      0.60      0.71       139
#           12       0.76      0.85      0.80       157
#           13       0.75      0.68      0.72       157
#           14       0.64      0.63      0.64       141
#           15       0.69      0.70      0.69       164
#           16       0.73      0.79      0.76       118
#           17       0.52      0.49      0.50       138
#           18       0.81      0.76      0.78       158
#           19       0.70      0.49      0.58       140
#           20       0.90      0.66      0.76       149
#           21       0.63      0.70      0.66       159
#           22       0.85      0.99      0.92       143
#           23       0.56      0.68      0.61       149
#           24       0.60      0.67      0.64       143
#           25       0.94      0.90      0.92       167
#           26       0.71      0.71      0.71       148
#           27       0.76      0.66      0.71       149
#           28       0.77      0.78      0.78       147
#           29       0.61      0.82      0.70       137
#           30       0.68      0.78      0.73       121
#           31       0.61      0.65      0.63       147
#           32       0.58      0.72      0.64       163
#           33       0.71      0.86      0.78       136
#           34       0.78      0.85      0.82       131
#           35       0.77      0.67      0.72       134
#           36       0.88      0.89      0.89       112
#           37       0.69      0.82      0.75       131
#
#     accuracy                           0.72      5469
#    macro avg       0.73      0.72      0.72      5469
# weighted avg       0.73      0.72      0.72      5469

# %%
# Calculate accuracy using sklearn
accuracy = accuracy_score(y_true_classes, y_pred_classes)
print('Accuracy:', accuracy)

# Calculate precision and recall using sklearn
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
print('Precision:', precision)
print('Recall:', recall)

# Append accuracy to a text file
with open(os.path.join(base_path, 'accuracy.txt'), 'a') as f:
    f.write(f'{model_name}_Accuracy: {accuracy:.2f}%\n')
    f.write(f'{model_name}_Precision: {precision:.2f}%\n')
    f.write(f'{model_name}_Recall: {recall:.2f}%\n')
# Out:
# Accuracy: 0.7244468824282319
# Precision: 0.7302841314912473
# Recall: 0.7244468824282319

# %%
# cnt = 0
# for i in range(len(y_pred_classes)):
#     print('예측 : ', y_pred_classes[i], "실제 :", y_true_classes[i])
#     if y_pred_classes[i] == y_true_classes[i]:
#         cnt += 1
# print('정확도', cnt / len(y_pred_classes) * 100, '%')

# with open(os.path.join(model_path, 'accuracy.txt'), 'w') as f:
#     f.write(f'{model}_Accuracy: {cnt / len(y_pred_classes) * 100:.2f}%\n')
