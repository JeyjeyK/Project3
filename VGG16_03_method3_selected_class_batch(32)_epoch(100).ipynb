# %% [markdown]
# https://www.kaggle.com/code/imsparsh/food-classifier-mobilenetv2-resnet50-vgg16

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import random

import tensorflow as tf
from tensorflow.keras import layers as k
from tensorflow.keras.applications import VGG16
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, classification_report

import json
import pickle
from tqdm import tqdm

import cv2
from google.colab.patches import cv2_imshow

import os
import warnings
warnings.filterwarnings('ignore')

import gc

seed = 42

# %%
image_size = (224, 224, 3)
batch_num = 32
epoch_num = 100

# create_model_name
model = 'VGG16'
numbering = '03'
preprocessing_method ='method3'
class_type = 'selected_class'

# 고정 내역
max_pic_cnt = 1000
top_layer = 'customized_top_layer'

model_name = f'{model}_{numbering}_{preprocessing_method}_{class_type}_batch({batch_num})_epoch({epoch_num})'
print(model_name)
# Out:
# VGG16_03_method3_selected_class_batch(32)_epoch(100)

# %%
# create model folder
base_path = f'/content/drive/MyDrive/project3/image_model/{model}'
if not os.path.exists(base_path):
    os.makedirs(base_path)

model_path = f'/content/drive/MyDrive/project3/image_model/{model}/{model_name}'
if not os.path.exists(model_path):
    os.makedirs(model_path)

# result folder
result_path = f'/content/drive/MyDrive/project3/image_model/{model}/{model_name}/result'
if not os.path.exists(result_path):
    os.makedirs(result_path)

# %% [markdown]
# ### data 준비

# %%
def get_image():
    pkl_dir_path = f'/content/drive/MyDrive/project3/data/traindata/image_to_list/{class_type}_square/{preprocessing_method}.pkl'
    df = pd.read_pickle(pkl_dir_path)

    image_list = np.array([x.reshape(224, 224, 3) for x in df['sq_list']])
    target_list = df['small_class']

    image_list = np.array(image_list).astype(np.uint8)
    target_list = np.array(target_list)

    return image_list, target_list


def prepare_data(test_size=0.2, random_state=42):
    # get_image 함수를 통해서 image / target 가져오기
    image_list, target_list = get_image()

    label_encoder = LabelEncoder()
    encoded_target_list = label_encoder.fit_transform(target_list)

    # Train-Test Split
    X_train, X_test, y_train, y_test = train_test_split(image_list, encoded_target_list, test_size=test_size, random_state=random_state)

    # image_array 정규화
    X_train = X_train / 255.0
    X_test = X_test / 255.0

    num_classes = len(np.unique(target_list))

    # target (one-hot encoding)
    y_train = to_categorical(y_train, num_classes)
    y_test = to_categorical(y_test, num_classes)

    return X_train, X_test, y_train, y_test, target_list, label_encoder

# 나중에 다시 label을 출력하기 위한 코드
def decode_labels(encoded_label, label_encoder):
    return label_encoder.inverse_transform(encoded_label)

# %%
X_train, X_test, y_train, y_test, target_list, label_encoder = prepare_data()
num_classes = len(np.unique(target_list))

print(f"X_train : {X_train.shape}")
print(f"X_test : {X_test.shape}")
print(f"y_train : {y_train.shape}")
print(f"y_test : {y_test.shape}")
print(f'Target count: {num_classes}')
# Out:
# X_train : (21876, 224, 224, 3)
# X_test : (5469, 224, 224, 3)
# y_train : (21876, 38)
# y_test : (5469, 38)
# Target count: 38

# %%
pic_num = 900
decoded_label = decode_labels([np.argmax(y_train[pic_num])], label_encoder)
print(f"Label: {decoded_label[0]}")
print(X_train[pic_num].shape)
cv2_imshow(X_train[pic_num] * 255)
# Out:
# Label: 육개장
# (224, 224, 3)
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# ### 모델 설계

# %%
# Load the VGG16
# model pre-trained -> by imagenet dataset
# without the top layer -> 마지막 결과를 내는 레이어 층에 관한
vgg16 = VGG16(weights='imagenet', input_shape=[224, 224, 3], include_top=False)
vgg16.trainable = False  # Freeze the layers of VGG16

# Define the Customized top layer
model = tf.keras.models.Sequential([
    vgg16,
    tf.keras.layers.GlobalAveragePooling2D(),
    k.Dropout(0.2),
    k.Dense(512, activation='relu'),
    k.BatchNormalization(),
    k.Dropout(0.1),
    k.Dense(256, activation='relu'),
    k.BatchNormalization(),
    k.Dropout(0.1),
    k.Dense(num_classes, activation='softmax')
])

print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 38)                9766
#
# =================================================================
# Total params: 15121510 (57.68 MB)
# Trainable params: 405286 (1.55 MB)
# Non-trainable params: 14716224 (56.14 MB)
# _________________________________________________________________
# None

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint(filepath=os.path.join(model_path, f'{model_name}_best.h5'),
                                   monitor='val_loss', save_best_only=True)


model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=[tf.keras.metrics.CategoricalAccuracy(), tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')]
)

history = model.fit(X_train, y_train, epochs= epoch_num, batch_size= batch_num, validation_split= 0.15,
                    callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/100
# 582/582 [==============================] - 31s 40ms/step - loss: 2.1770 - categorical_accuracy: 0.3923 - precision: 0.6732 - recall: 0.2189 - val_loss: 1.3619 - val_categorical_accuracy: 0.5929 - val_precision: 0.8007 - val_recall: 0.4247
# Epoch 2/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.6151 - categorical_accuracy: 0.5273 - precision: 0.7235 - recall: 0.3737 - val_loss: 1.2008 - val_categorical_accuracy: 0.6417 - val_precision: 0.8038 - val_recall: 0.5131
# Epoch 3/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.4778 - categorical_accuracy: 0.5632 - precision: 0.7421 - recall: 0.4215 - val_loss: 1.1650 - val_categorical_accuracy: 0.6533 - val_precision: 0.8124 - val_recall: 0.5158
# Epoch 4/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.3992 - categorical_accuracy: 0.5818 - precision: 0.7574 - recall: 0.4427 - val_loss: 1.1026 - val_categorical_accuracy: 0.6661 - val_precision: 0.8367 - val_recall: 0.5323
# Epoch 5/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.3539 - categorical_accuracy: 0.5924 - precision: 0.7612 - recall: 0.4542 - val_loss: 1.0842 - val_categorical_accuracy: 0.6816 - val_precision: 0.8262 - val_recall: 0.5475
# Epoch 6/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.3134 - categorical_accuracy: 0.6014 - precision: 0.7656 - recall: 0.4675 - val_loss: 1.1138 - val_categorical_accuracy: 0.6725 - val_precision: 0.8234 - val_recall: 0.5454
# Epoch 7/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.2794 - categorical_accuracy: 0.6138 - precision: 0.7712 - recall: 0.4811 - val_loss: 1.0384 - val_categorical_accuracy: 0.6907 - val_precision: 0.8281 - val_recall: 0.5768
# Epoch 8/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.2643 - categorical_accuracy: 0.6157 - precision: 0.7737 - recall: 0.4899 - val_loss: 1.0436 - val_categorical_accuracy: 0.6862 - val_precision: 0.8282 - val_recall: 0.5683
# Epoch 9/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.2471 - categorical_accuracy: 0.6204 - precision: 0.7785 - recall: 0.4973 - val_loss: 1.0213 - val_categorical_accuracy: 0.6965 - val_precision: 0.8223 - val_recall: 0.5838
# Epoch 10/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.2143 - categorical_accuracy: 0.6309 - precision: 0.7836 - recall: 0.5072 - val_loss: 1.0462 - val_categorical_accuracy: 0.6807 - val_precision: 0.8151 - val_recall: 0.5789
# Epoch 11/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.2146 - categorical_accuracy: 0.6318 - precision: 0.7825 - recall: 0.5097 - val_loss: 1.0449 - val_categorical_accuracy: 0.6889 - val_precision: 0.8258 - val_recall: 0.5649
# Epoch 12/100
# 582/582 [==============================] - 18s 30ms/step - loss: 1.1953 - categorical_accuracy: 0.6311 - precision: 0.7777 - recall: 0.5103 - val_loss: 1.0170 - val_categorical_accuracy: 0.6953 - val_precision: 0.8263 - val_recall: 0.5826
# Epoch 13/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.1867 - categorical_accuracy: 0.6362 - precision: 0.7828 - recall: 0.5148 - val_loss: 0.9861 - val_categorical_accuracy: 0.7096 - val_precision: 0.8319 - val_recall: 0.6030
# Epoch 14/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.1662 - categorical_accuracy: 0.6453 - precision: 0.7907 - recall: 0.5254 - val_loss: 1.0221 - val_categorical_accuracy: 0.6929 - val_precision: 0.8260 - val_recall: 0.5817
# Epoch 15/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.1452 - categorical_accuracy: 0.6485 - precision: 0.7900 - recall: 0.5333 - val_loss: 1.0111 - val_categorical_accuracy: 0.7020 - val_precision: 0.8192 - val_recall: 0.5993
# Epoch 16/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.1373 - categorical_accuracy: 0.6517 - precision: 0.7904 - recall: 0.5329 - val_loss: 0.9827 - val_categorical_accuracy: 0.7023 - val_precision: 0.8301 - val_recall: 0.5941
# Epoch 17/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.1341 - categorical_accuracy: 0.6516 - precision: 0.7919 - recall: 0.5396 - val_loss: 1.0028 - val_categorical_accuracy: 0.7002 - val_precision: 0.8193 - val_recall: 0.5911
# Epoch 18/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.1216 - categorical_accuracy: 0.6557 - precision: 0.7922 - recall: 0.5418 - val_loss: 0.9599 - val_categorical_accuracy: 0.7154 - val_precision: 0.8430 - val_recall: 0.6133
# Epoch 19/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0991 - categorical_accuracy: 0.6661 - precision: 0.7968 - recall: 0.5532 - val_loss: 0.9698 - val_categorical_accuracy: 0.7096 - val_precision: 0.8306 - val_recall: 0.6094
# Epoch 20/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0883 - categorical_accuracy: 0.6623 - precision: 0.7995 - recall: 0.5503 - val_loss: 0.9511 - val_categorical_accuracy: 0.7169 - val_precision: 0.8367 - val_recall: 0.6149
# Epoch 21/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0886 - categorical_accuracy: 0.6633 - precision: 0.7975 - recall: 0.5596 - val_loss: 1.0169 - val_categorical_accuracy: 0.6907 - val_precision: 0.8275 - val_recall: 0.5774
# Epoch 22/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0719 - categorical_accuracy: 0.6670 - precision: 0.7968 - recall: 0.5623 - val_loss: 0.9503 - val_categorical_accuracy: 0.7136 - val_precision: 0.8359 - val_recall: 0.6191
# Epoch 23/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0663 - categorical_accuracy: 0.6689 - precision: 0.8002 - recall: 0.5636 - val_loss: 0.9923 - val_categorical_accuracy: 0.7069 - val_precision: 0.8118 - val_recall: 0.6124
# Epoch 24/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0629 - categorical_accuracy: 0.6720 - precision: 0.7996 - recall: 0.5653 - val_loss: 0.9257 - val_categorical_accuracy: 0.7218 - val_precision: 0.8325 - val_recall: 0.6301
# Epoch 25/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0661 - categorical_accuracy: 0.6717 - precision: 0.7993 - recall: 0.5667 - val_loss: 0.9516 - val_categorical_accuracy: 0.7221 - val_precision: 0.8395 - val_recall: 0.6200
# Epoch 26/100
# 582/582 [==============================] - 17s 28ms/step - loss: 1.0526 - categorical_accuracy: 0.6718 - precision: 0.8008 - recall: 0.5672 - val_loss: 0.9617 - val_categorical_accuracy: 0.7157 - val_precision: 0.8307 - val_recall: 0.6130
# Epoch 27/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0500 - categorical_accuracy: 0.6767 - precision: 0.7986 - recall: 0.5716 - val_loss: 0.9669 - val_categorical_accuracy: 0.7118 - val_precision: 0.8298 - val_recall: 0.6179
# Epoch 28/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0281 - categorical_accuracy: 0.6814 - precision: 0.8061 - recall: 0.5803 - val_loss: 0.9420 - val_categorical_accuracy: 0.7188 - val_precision: 0.8288 - val_recall: 0.6255
# Epoch 29/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0260 - categorical_accuracy: 0.6826 - precision: 0.8021 - recall: 0.5810 - val_loss: 0.9711 - val_categorical_accuracy: 0.7017 - val_precision: 0.8209 - val_recall: 0.6228
# Epoch 30/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0213 - categorical_accuracy: 0.6833 - precision: 0.8053 - recall: 0.5810 - val_loss: 0.9255 - val_categorical_accuracy: 0.7297 - val_precision: 0.8363 - val_recall: 0.6289
# Epoch 31/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0257 - categorical_accuracy: 0.6810 - precision: 0.8019 - recall: 0.5841 - val_loss: 0.9376 - val_categorical_accuracy: 0.7215 - val_precision: 0.8283 - val_recall: 0.6304
# Epoch 32/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0065 - categorical_accuracy: 0.6895 - precision: 0.8091 - recall: 0.5872 - val_loss: 0.9260 - val_categorical_accuracy: 0.7294 - val_precision: 0.8285 - val_recall: 0.6359
# Epoch 33/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9926 - categorical_accuracy: 0.6917 - precision: 0.8106 - recall: 0.5929 - val_loss: 0.9378 - val_categorical_accuracy: 0.7246 - val_precision: 0.8320 - val_recall: 0.6322
# Epoch 34/100
# 582/582 [==============================] - 18s 30ms/step - loss: 0.9926 - categorical_accuracy: 0.6912 - precision: 0.8076 - recall: 0.5931 - val_loss: 0.9196 - val_categorical_accuracy: 0.7288 - val_precision: 0.8296 - val_recall: 0.6377
# Epoch 35/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9936 - categorical_accuracy: 0.6929 - precision: 0.8060 - recall: 0.5945 - val_loss: 0.9256 - val_categorical_accuracy: 0.7246 - val_precision: 0.8285 - val_recall: 0.6478
# Epoch 36/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9866 - categorical_accuracy: 0.6935 - precision: 0.8065 - recall: 0.5960 - val_loss: 0.9492 - val_categorical_accuracy: 0.7230 - val_precision: 0.8177 - val_recall: 0.6368
# Epoch 37/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9836 - categorical_accuracy: 0.6922 - precision: 0.8040 - recall: 0.5951 - val_loss: 0.9548 - val_categorical_accuracy: 0.7176 - val_precision: 0.8294 - val_recall: 0.6310
# Epoch 38/100
# 582/582 [==============================] - 17s 28ms/step - loss: 0.9832 - categorical_accuracy: 0.6942 - precision: 0.8064 - recall: 0.5993 - val_loss: 0.9234 - val_categorical_accuracy: 0.7276 - val_precision: 0.8381 - val_recall: 0.6420
# Epoch 39/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9815 - categorical_accuracy: 0.6919 - precision: 0.8074 - recall: 0.5948 - val_loss: 0.9535 - val_categorical_accuracy: 0.7191 - val_precision: 0.8283 - val_recall: 0.6246
# Epoch 40/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9755 - categorical_accuracy: 0.6972 - precision: 0.8114 - recall: 0.6006 - val_loss: 0.9750 - val_categorical_accuracy: 0.7139 - val_precision: 0.8132 - val_recall: 0.6353
# Epoch 41/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9636 - categorical_accuracy: 0.7001 - precision: 0.8118 - recall: 0.6021 - val_loss: 0.9643 - val_categorical_accuracy: 0.7209 - val_precision: 0.8193 - val_recall: 0.6426
# Epoch 42/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9567 - categorical_accuracy: 0.7005 - precision: 0.8154 - recall: 0.6116 - val_loss: 0.9467 - val_categorical_accuracy: 0.7239 - val_precision: 0.8294 - val_recall: 0.6399
# Epoch 43/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9663 - categorical_accuracy: 0.6968 - precision: 0.8060 - recall: 0.6034 - val_loss: 0.9538 - val_categorical_accuracy: 0.7191 - val_precision: 0.8185 - val_recall: 0.6402
# Epoch 44/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9530 - categorical_accuracy: 0.7002 - precision: 0.8096 - recall: 0.6091 - val_loss: 0.9346 - val_categorical_accuracy: 0.7279 - val_precision: 0.8266 - val_recall: 0.6450

# %%
# model save
model.save(os.path.join(model_path, f'{model_name}.h5'))


# training history save
with open(os.path.join(result_path, f'{model_name}_history.json'), 'w') as f:
    json.dump(history.history, f)

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['categorical_accuracy'], label='Train Accuracy')
plt.plot(history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy By Epochs')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss By Epochs')

plt.suptitle(f'{model_name}')

# save training_plot
plt.savefig(os.path.join(result_path, f'{model_name}_training_plot.png'))
plt.show()

# %%
y_pred = model.predict(X_test)

# Convert one-hot encoded predictions and actual values to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# Print classification report for detailed metrics
class_report = classification_report(y_true_classes, y_pred_classes)
print(class_report)

with open(os.path.join(result_path, f'{model_name}_classification_report.txt'), 'w') as f:
    f.write(class_report)

# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title(f'{model_name}_Confusion Matrix')


plt.savefig(os.path.join(result_path, f'{model_name}_confusion_matrix.png'))
plt.show()
# Out:
# 171/171 [==============================] - 5s 28ms/step
#               precision    recall  f1-score   support
#
#            0       0.71      0.72      0.71       135
#            1       0.41      0.56      0.47       129
#            2       0.69      0.80      0.74       169
#            3       0.51      0.58      0.54       125
#            4       0.87      0.77      0.82       180
#            5       0.82      0.93      0.87       140
#            6       0.79      0.73      0.76       131
#            7       0.72      0.84      0.78       128
#            8       0.79      0.69      0.74       148
#            9       0.66      0.71      0.69       147
#           10       0.62      0.62      0.62       159
#           11       0.64      0.74      0.69       139
#           12       0.80      0.78      0.79       157
#           13       0.73      0.75      0.74       157
#           14       0.60      0.62      0.61       141
#           15       0.83      0.59      0.69       164
#           16       0.81      0.74      0.77       118
#           17       0.57      0.51      0.54       138
#           18       0.63      0.77      0.69       158
#           19       0.68      0.49      0.57       140
#           20       0.75      0.74      0.75       149
#           21       0.50      0.76      0.61       159
#           22       0.98      0.99      0.99       143
#           23       0.74      0.46      0.56       149
#           24       0.53      0.71      0.60       143
#           25       0.96      0.87      0.91       167
#           26       0.79      0.66      0.72       148
#           27       0.82      0.64      0.72       149
#           28       0.73      0.80      0.76       147
#           29       0.81      0.64      0.72       137
#           30       0.78      0.63      0.70       121
#           31       0.70      0.75      0.72       147
#           32       0.69      0.50      0.58       163
#           33       0.79      0.71      0.75       136
#           34       0.81      0.83      0.82       131
#           35       0.76      0.78      0.77       134
#           36       0.86      0.85      0.86       112
#           37       0.64      0.80      0.71       131
#
#     accuracy                           0.71      5469
#    macro avg       0.72      0.71      0.71      5469
# weighted avg       0.73      0.71      0.71      5469

# %%
# Calculate accuracy using sklearn
accuracy = accuracy_score(y_true_classes, y_pred_classes)
print('Accuracy:', accuracy)

# Calculate precision and recall using sklearn
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
print('Precision:', precision)
print('Recall:', recall)

# Append accuracy to a text file
with open(os.path.join(base_path, 'accuracy.txt'), 'a') as f:
    f.write(f'{model_name}_Accuracy: {accuracy:.2f}%\n')
    f.write(f'{model_name}_Precision: {precision:.2f}%\n')
    f.write(f'{model_name}_Recall: {recall:.2f}%\n')
# Out:
# Accuracy: 0.7121960138965076
# Precision: 0.7259264404510835
# Recall: 0.7121960138965076

# %%
# cnt = 0
# for i in range(len(y_pred_classes)):
#     print('예측 : ', y_pred_classes[i], "실제 :", y_true_classes[i])
#     if y_pred_classes[i] == y_true_classes[i]:
#         cnt += 1
# print('정확도', cnt / len(y_pred_classes) * 100, '%')

# with open(os.path.join(model_path, 'accuracy.txt'), 'w') as f:
#     f.write(f'{model}_Accuracy: {cnt / len(y_pred_classes) * 100:.2f}%\n')
