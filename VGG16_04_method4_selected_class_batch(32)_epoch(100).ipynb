# %% [markdown]
# https://www.kaggle.com/code/imsparsh/food-classifier-mobilenetv2-resnet50-vgg16

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import random

import tensorflow as tf
from tensorflow.keras import layers as k
from tensorflow.keras.applications import VGG16
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, classification_report

import json
import pickle
from tqdm import tqdm

import cv2
from google.colab.patches import cv2_imshow

import os
import warnings
warnings.filterwarnings('ignore')

import gc

seed = 42

# %%
image_size = (224, 224, 3)
batch_num = 32
epoch_num = 100

# create_model_name
model = 'VGG16'
numbering = '04'
preprocessing_method ='method4'
class_type = 'selected_class'

# 고정 내역
max_pic_cnt = 1000
top_layer = 'customized_top_layer'

model_name = f'{model}_{numbering}_{preprocessing_method}_{class_type}_batch({batch_num})_epoch({epoch_num})'
print(model_name)
# Out:
# VGG16_04_method4_selected_class_batch(32)_epoch(100)

# %%
# create model folder
base_path = f'/content/drive/MyDrive/project3/image_model/{model}'
if not os.path.exists(base_path):
    os.makedirs(base_path)

model_path = f'/content/drive/MyDrive/project3/image_model/{model}/{model_name}'
if not os.path.exists(model_path):
    os.makedirs(model_path)

# result folder
result_path = f'/content/drive/MyDrive/project3/image_model/{model}/{model_name}/result'
if not os.path.exists(result_path):
    os.makedirs(result_path)

# %% [markdown]
# ### data 준비

# %%
def get_image():
    pkl_dir_path = f'/content/drive/MyDrive/project3/data/traindata/image_to_list/{class_type}_square/{preprocessing_method}.pkl'
    df = pd.read_pickle(pkl_dir_path)

    image_list = np.array([x.reshape(224, 224, 3) for x in df['sq_list']])
    target_list = df['small_class']

    image_list = np.array(image_list).astype(np.uint8)
    target_list = np.array(target_list)

    return image_list, target_list


def prepare_data(test_size=0.2, random_state=42):
    # get_image 함수를 통해서 image / target 가져오기
    image_list, target_list = get_image()

    label_encoder = LabelEncoder()
    encoded_target_list = label_encoder.fit_transform(target_list)

    # Train-Test Split
    X_train, X_test, y_train, y_test = train_test_split(image_list, encoded_target_list, test_size=test_size, random_state=random_state)

    # image_array 정규화
    X_train = X_train / 255.0
    X_test = X_test / 255.0

    num_classes = len(np.unique(target_list))

    # target (one-hot encoding)
    y_train = to_categorical(y_train, num_classes)
    y_test = to_categorical(y_test, num_classes)

    return X_train, X_test, y_train, y_test, target_list, label_encoder

# 나중에 다시 label을 출력하기 위한 코드
def decode_labels(encoded_label, label_encoder):
    return label_encoder.inverse_transform(encoded_label)

# %%
X_train, X_test, y_train, y_test, target_list, label_encoder = prepare_data()
num_classes = len(np.unique(target_list))

print(f"X_train : {X_train.shape}")
print(f"X_test : {X_test.shape}")
print(f"y_train : {y_train.shape}")
print(f"y_test : {y_test.shape}")
print(f'Target count: {num_classes}')
# Out:
# X_train : (21876, 224, 224, 3)
# X_test : (5469, 224, 224, 3)
# y_train : (21876, 38)
# y_test : (5469, 38)
# Target count: 38

# %%
pic_num = 900
decoded_label = decode_labels([np.argmax(y_train[pic_num])], label_encoder)
print(f"Label: {decoded_label[0]}")
print(X_train[pic_num].shape)
cv2_imshow(X_train[pic_num] * 255)
# Out:
# Label: 육개장
# (224, 224, 3)
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# ### 모델 설계

# %%
# Load the VGG16
# model pre-trained -> by imagenet dataset
# without the top layer -> 마지막 결과를 내는 레이어 층에 관한
vgg16 = VGG16(weights='imagenet', input_shape=[224, 224, 3], include_top=False)
vgg16.trainable = False  # Freeze the layers of VGG16

# Define the Customized top layer
model = tf.keras.models.Sequential([
    vgg16,
    tf.keras.layers.GlobalAveragePooling2D(),
    k.Dropout(0.2),
    k.Dense(512, activation='relu'),
    k.BatchNormalization(),
    k.Dropout(0.1),
    k.Dense(256, activation='relu'),
    k.BatchNormalization(),
    k.Dropout(0.1),
    k.Dense(num_classes, activation='softmax')
])

print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 38)                9766
#
# =================================================================
# Total params: 15121510 (57.68 MB)
# Trainable params: 405286 (1.55 MB)
# Non-trainable params: 14716224 (56.14 MB)
# _________________________________________________________________
# None

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint(filepath=os.path.join(model_path, f'{model_name}_best.h5'),
                                   monitor='val_loss', save_best_only=True)


model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=[tf.keras.metrics.CategoricalAccuracy(), tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')]
)

history = model.fit(X_train, y_train, epochs= epoch_num, batch_size= batch_num, validation_split= 0.15,
                    callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/100
# 582/582 [==============================] - 30s 40ms/step - loss: 2.2417 - categorical_accuracy: 0.3767 - precision: 0.6586 - recall: 0.1980 - val_loss: 1.4668 - val_categorical_accuracy: 0.5679 - val_precision: 0.7943 - val_recall: 0.3882
# Epoch 2/100
# 582/582 [==============================] - 19s 32ms/step - loss: 1.6685 - categorical_accuracy: 0.5131 - precision: 0.7188 - recall: 0.3550 - val_loss: 1.3018 - val_categorical_accuracy: 0.6197 - val_precision: 0.7983 - val_recall: 0.4668
# Epoch 3/100
# 582/582 [==============================] - 18s 32ms/step - loss: 1.5199 - categorical_accuracy: 0.5502 - precision: 0.7382 - recall: 0.4042 - val_loss: 1.1939 - val_categorical_accuracy: 0.6450 - val_precision: 0.8145 - val_recall: 0.5070
# Epoch 4/100
# 582/582 [==============================] - 19s 32ms/step - loss: 1.4401 - categorical_accuracy: 0.5713 - precision: 0.7505 - recall: 0.4240 - val_loss: 1.1179 - val_categorical_accuracy: 0.6712 - val_precision: 0.8363 - val_recall: 0.5338
# Epoch 5/100
# 582/582 [==============================] - 19s 32ms/step - loss: 1.3958 - categorical_accuracy: 0.5837 - precision: 0.7625 - recall: 0.4400 - val_loss: 1.1143 - val_categorical_accuracy: 0.6685 - val_precision: 0.8238 - val_recall: 0.5201
# Epoch 6/100
# 582/582 [==============================] - 17s 30ms/step - loss: 1.3499 - categorical_accuracy: 0.5945 - precision: 0.7659 - recall: 0.4553 - val_loss: 1.1458 - val_categorical_accuracy: 0.6560 - val_precision: 0.8047 - val_recall: 0.5335
# Epoch 7/100
# 582/582 [==============================] - 19s 32ms/step - loss: 1.3267 - categorical_accuracy: 0.6035 - precision: 0.7747 - recall: 0.4655 - val_loss: 1.0983 - val_categorical_accuracy: 0.6670 - val_precision: 0.8217 - val_recall: 0.5518
# Epoch 8/100
# 582/582 [==============================] - 19s 32ms/step - loss: 1.3171 - categorical_accuracy: 0.6018 - precision: 0.7646 - recall: 0.4719 - val_loss: 1.0616 - val_categorical_accuracy: 0.6871 - val_precision: 0.8311 - val_recall: 0.5591
# Epoch 9/100
# 582/582 [==============================] - 19s 32ms/step - loss: 1.2858 - categorical_accuracy: 0.6152 - precision: 0.7745 - recall: 0.4800 - val_loss: 1.0565 - val_categorical_accuracy: 0.6822 - val_precision: 0.8362 - val_recall: 0.5695
# Epoch 10/100
# 582/582 [==============================] - 19s 32ms/step - loss: 1.2611 - categorical_accuracy: 0.6160 - precision: 0.7739 - recall: 0.4855 - val_loss: 1.0447 - val_categorical_accuracy: 0.6859 - val_precision: 0.8370 - val_recall: 0.5615
# Epoch 11/100
# 582/582 [==============================] - 19s 32ms/step - loss: 1.2368 - categorical_accuracy: 0.6209 - precision: 0.7814 - recall: 0.4982 - val_loss: 1.0243 - val_categorical_accuracy: 0.6959 - val_precision: 0.8260 - val_recall: 0.5874
# Epoch 12/100
# 582/582 [==============================] - 17s 30ms/step - loss: 1.2068 - categorical_accuracy: 0.6335 - precision: 0.7849 - recall: 0.5095 - val_loss: 1.0300 - val_categorical_accuracy: 0.6917 - val_precision: 0.8192 - val_recall: 0.5756
# Epoch 13/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.2033 - categorical_accuracy: 0.6358 - precision: 0.7864 - recall: 0.5111 - val_loss: 1.0443 - val_categorical_accuracy: 0.6837 - val_precision: 0.8234 - val_recall: 0.5795
# Epoch 14/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.1944 - categorical_accuracy: 0.6365 - precision: 0.7807 - recall: 0.5141 - val_loss: 1.0059 - val_categorical_accuracy: 0.6999 - val_precision: 0.8316 - val_recall: 0.6005
# Epoch 15/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.1795 - categorical_accuracy: 0.6420 - precision: 0.7877 - recall: 0.5161 - val_loss: 1.0437 - val_categorical_accuracy: 0.6862 - val_precision: 0.8318 - val_recall: 0.5710
# Epoch 16/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.1645 - categorical_accuracy: 0.6472 - precision: 0.7906 - recall: 0.5293 - val_loss: 1.0102 - val_categorical_accuracy: 0.6923 - val_precision: 0.8301 - val_recall: 0.5850
# Epoch 17/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.1446 - categorical_accuracy: 0.6489 - precision: 0.7897 - recall: 0.5308 - val_loss: 1.0007 - val_categorical_accuracy: 0.6935 - val_precision: 0.8323 - val_recall: 0.5881
# Epoch 18/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.1546 - categorical_accuracy: 0.6429 - precision: 0.7886 - recall: 0.5279 - val_loss: 1.0128 - val_categorical_accuracy: 0.7032 - val_precision: 0.8253 - val_recall: 0.5987
# Epoch 19/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.1379 - categorical_accuracy: 0.6510 - precision: 0.7966 - recall: 0.5391 - val_loss: 0.9982 - val_categorical_accuracy: 0.7029 - val_precision: 0.8266 - val_recall: 0.6030
# Epoch 20/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.1306 - categorical_accuracy: 0.6559 - precision: 0.7966 - recall: 0.5428 - val_loss: 1.0766 - val_categorical_accuracy: 0.6734 - val_precision: 0.7986 - val_recall: 0.5920
# Epoch 21/100
# 582/582 [==============================] - 18s 32ms/step - loss: 1.1149 - categorical_accuracy: 0.6571 - precision: 0.7965 - recall: 0.5425 - val_loss: 0.9773 - val_categorical_accuracy: 0.7005 - val_precision: 0.8160 - val_recall: 0.5984
# Epoch 22/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.1031 - categorical_accuracy: 0.6593 - precision: 0.8000 - recall: 0.5489 - val_loss: 0.9861 - val_categorical_accuracy: 0.7075 - val_precision: 0.8238 - val_recall: 0.5969
# Epoch 23/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.1020 - categorical_accuracy: 0.6637 - precision: 0.7935 - recall: 0.5533 - val_loss: 1.0061 - val_categorical_accuracy: 0.6920 - val_precision: 0.8292 - val_recall: 0.6005
# Epoch 24/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0881 - categorical_accuracy: 0.6645 - precision: 0.7973 - recall: 0.5525 - val_loss: 1.0154 - val_categorical_accuracy: 0.6947 - val_precision: 0.8143 - val_recall: 0.6027
# Epoch 25/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0706 - categorical_accuracy: 0.6660 - precision: 0.7943 - recall: 0.5593 - val_loss: 1.0049 - val_categorical_accuracy: 0.7002 - val_precision: 0.8235 - val_recall: 0.5984
# Epoch 26/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0727 - categorical_accuracy: 0.6678 - precision: 0.7968 - recall: 0.5619 - val_loss: 0.9736 - val_categorical_accuracy: 0.7087 - val_precision: 0.8226 - val_recall: 0.6204
# Epoch 27/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0619 - categorical_accuracy: 0.6685 - precision: 0.8008 - recall: 0.5644 - val_loss: 1.0095 - val_categorical_accuracy: 0.6999 - val_precision: 0.8157 - val_recall: 0.6042
# Epoch 28/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0700 - categorical_accuracy: 0.6699 - precision: 0.7958 - recall: 0.5614 - val_loss: 0.9834 - val_categorical_accuracy: 0.7038 - val_precision: 0.8205 - val_recall: 0.6057
# Epoch 29/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0539 - categorical_accuracy: 0.6761 - precision: 0.8010 - recall: 0.5666 - val_loss: 0.9775 - val_categorical_accuracy: 0.7072 - val_precision: 0.8287 - val_recall: 0.6115
# Epoch 30/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0481 - categorical_accuracy: 0.6746 - precision: 0.7981 - recall: 0.5756 - val_loss: 0.9925 - val_categorical_accuracy: 0.7002 - val_precision: 0.8178 - val_recall: 0.6155
# Epoch 31/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0349 - categorical_accuracy: 0.6768 - precision: 0.8020 - recall: 0.5735 - val_loss: 1.0061 - val_categorical_accuracy: 0.6977 - val_precision: 0.8279 - val_recall: 0.5996
# Epoch 32/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0415 - categorical_accuracy: 0.6767 - precision: 0.8001 - recall: 0.5755 - val_loss: 0.9721 - val_categorical_accuracy: 0.7096 - val_precision: 0.8342 - val_recall: 0.6222
# Epoch 33/100
# 582/582 [==============================] - 18s 32ms/step - loss: 1.0356 - categorical_accuracy: 0.6788 - precision: 0.8036 - recall: 0.5772 - val_loss: 0.9711 - val_categorical_accuracy: 0.7069 - val_precision: 0.8294 - val_recall: 0.6133
# Epoch 34/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0295 - categorical_accuracy: 0.6798 - precision: 0.8062 - recall: 0.5778 - val_loss: 0.9767 - val_categorical_accuracy: 0.7112 - val_precision: 0.8206 - val_recall: 0.6243
# Epoch 35/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0217 - categorical_accuracy: 0.6805 - precision: 0.7987 - recall: 0.5787 - val_loss: 0.9989 - val_categorical_accuracy: 0.7057 - val_precision: 0.8199 - val_recall: 0.6185
# Epoch 36/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0163 - categorical_accuracy: 0.6832 - precision: 0.8021 - recall: 0.5819 - val_loss: 0.9523 - val_categorical_accuracy: 0.7203 - val_precision: 0.8241 - val_recall: 0.6280
# Epoch 37/100
# 582/582 [==============================] - 17s 29ms/step - loss: 1.0244 - categorical_accuracy: 0.6804 - precision: 0.7966 - recall: 0.5812 - val_loss: 0.9946 - val_categorical_accuracy: 0.7072 - val_precision: 0.8194 - val_recall: 0.6194
# Epoch 38/100
# 582/582 [==============================] - 17s 30ms/step - loss: 1.0099 - categorical_accuracy: 0.6833 - precision: 0.8042 - recall: 0.5840 - val_loss: 0.9567 - val_categorical_accuracy: 0.7087 - val_precision: 0.8151 - val_recall: 0.6301
# Epoch 39/100
# 582/582 [==============================] - 17s 30ms/step - loss: 0.9945 - categorical_accuracy: 0.6888 - precision: 0.8057 - recall: 0.5886 - val_loss: 0.9608 - val_categorical_accuracy: 0.7108 - val_precision: 0.8225 - val_recall: 0.6271
# Epoch 40/100
# 582/582 [==============================] - 17s 30ms/step - loss: 0.9863 - categorical_accuracy: 0.6880 - precision: 0.8095 - recall: 0.5941 - val_loss: 0.9658 - val_categorical_accuracy: 0.7090 - val_precision: 0.8231 - val_recall: 0.6237
# Epoch 41/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9952 - categorical_accuracy: 0.6896 - precision: 0.8013 - recall: 0.5909 - val_loss: 0.9822 - val_categorical_accuracy: 0.7063 - val_precision: 0.8119 - val_recall: 0.6301
# Epoch 42/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.9951 - categorical_accuracy: 0.6918 - precision: 0.8090 - recall: 0.5975 - val_loss: 0.9486 - val_categorical_accuracy: 0.7218 - val_precision: 0.8370 - val_recall: 0.6292
# Epoch 43/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9726 - categorical_accuracy: 0.6964 - precision: 0.8127 - recall: 0.5979 - val_loss: 0.9528 - val_categorical_accuracy: 0.7212 - val_precision: 0.8358 - val_recall: 0.6450
# Epoch 44/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9671 - categorical_accuracy: 0.6979 - precision: 0.8121 - recall: 0.6020 - val_loss: 0.9918 - val_categorical_accuracy: 0.6996 - val_precision: 0.8089 - val_recall: 0.6243
# Epoch 45/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9714 - categorical_accuracy: 0.6954 - precision: 0.8118 - recall: 0.6020 - val_loss: 0.9626 - val_categorical_accuracy: 0.7063 - val_precision: 0.8127 - val_recall: 0.6252
# Epoch 46/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9737 - categorical_accuracy: 0.6935 - precision: 0.8087 - recall: 0.5999 - val_loss: 0.9699 - val_categorical_accuracy: 0.7081 - val_precision: 0.8203 - val_recall: 0.6328
# Epoch 47/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.9661 - categorical_accuracy: 0.6989 - precision: 0.8077 - recall: 0.6034 - val_loss: 0.9479 - val_categorical_accuracy: 0.7185 - val_precision: 0.8250 - val_recall: 0.6322
# Epoch 48/100
# 582/582 [==============================] - 17s 30ms/step - loss: 0.9541 - categorical_accuracy: 0.6989 - precision: 0.8112 - recall: 0.6046 - val_loss: 0.9680 - val_categorical_accuracy: 0.7087 - val_precision: 0.8121 - val_recall: 0.6255
# Epoch 49/100
# 582/582 [==============================] - 17s 30ms/step - loss: 0.9360 - categorical_accuracy: 0.7060 - precision: 0.8162 - recall: 0.6086 - val_loss: 0.9742 - val_categorical_accuracy: 0.7072 - val_precision: 0.8172 - val_recall: 0.6280
# Epoch 50/100
# 582/582 [==============================] - 19s 32ms/step - loss: 0.9698 - categorical_accuracy: 0.6994 - precision: 0.8054 - recall: 0.6061 - val_loss: 0.9369 - val_categorical_accuracy: 0.7172 - val_precision: 0.8219 - val_recall: 0.6383
# Epoch 51/100
# 582/582 [==============================] - 17s 30ms/step - loss: 0.9384 - categorical_accuracy: 0.7015 - precision: 0.8121 - recall: 0.6110 - val_loss: 0.9516 - val_categorical_accuracy: 0.7169 - val_precision: 0.8213 - val_recall: 0.6359
# Epoch 52/100
# 582/582 [==============================] - 17s 30ms/step - loss: 0.9308 - categorical_accuracy: 0.7075 - precision: 0.8162 - recall: 0.6185 - val_loss: 0.9471 - val_categorical_accuracy: 0.7151 - val_precision: 0.8185 - val_recall: 0.6459
# Epoch 53/100
# 582/582 [==============================] - 17s 30ms/step - loss: 0.9422 - categorical_accuracy: 0.7021 - precision: 0.8131 - recall: 0.6125 - val_loss: 0.9645 - val_categorical_accuracy: 0.7096 - val_precision: 0.8195 - val_recall: 0.6350
# Epoch 54/100
# 582/582 [==============================] - 17s 30ms/step - loss: 0.9226 - categorical_accuracy: 0.7095 - precision: 0.8133 - recall: 0.6196 - val_loss: 0.9425 - val_categorical_accuracy: 0.7255 - val_precision: 0.8262 - val_recall: 0.6417
# Epoch 55/100
# 582/582 [==============================] - 17s 30ms/step - loss: 0.9365 - categorical_accuracy: 0.7019 - precision: 0.8090 - recall: 0.6139 - val_loss: 0.9477 - val_categorical_accuracy: 0.7166 - val_precision: 0.8254 - val_recall: 0.6395
# Epoch 56/100
# 582/582 [==============================] - 17s 30ms/step - loss: 0.9429 - categorical_accuracy: 0.7035 - precision: 0.8103 - recall: 0.6141 - val_loss: 0.9978 - val_categorical_accuracy: 0.6996 - val_precision: 0.8092 - val_recall: 0.6295
# Epoch 57/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9172 - categorical_accuracy: 0.7088 - precision: 0.8191 - recall: 0.6224 - val_loss: 0.9568 - val_categorical_accuracy: 0.7163 - val_precision: 0.8261 - val_recall: 0.6341
# Epoch 58/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9349 - categorical_accuracy: 0.7064 - precision: 0.8180 - recall: 0.6189 - val_loss: 0.9435 - val_categorical_accuracy: 0.7169 - val_precision: 0.8370 - val_recall: 0.6353
# Epoch 59/100
# 582/582 [==============================] - 17s 29ms/step - loss: 0.9210 - categorical_accuracy: 0.7093 - precision: 0.8146 - recall: 0.6231 - val_loss: 0.9526 - val_categorical_accuracy: 0.7203 - val_precision: 0.8243 - val_recall: 0.6463
# Epoch 60/100
# 582/582 [==============================] - 17s 30ms/step - loss: 0.9006 - categorical_accuracy: 0.7163 - precision: 0.8197 - recall: 0.6256 - val_loss: 0.9458 - val_categorical_accuracy: 0.7176 - val_precision: 0.8284 - val_recall: 0.6441

# %%
# model save
model.save(os.path.join(model_path, f'{model_name}.h5'))


# training history save
with open(os.path.join(result_path, f'{model_name}_history.json'), 'w') as f:
    json.dump(history.history, f)

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['categorical_accuracy'], label='Train Accuracy')
plt.plot(history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy By Epochs')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss By Epochs')

plt.suptitle(f'{model_name}')

# save training_plot
plt.savefig(os.path.join(result_path, f'{model_name}_training_plot.png'))
plt.show()

# %%
y_pred = model.predict(X_test)

# Convert one-hot encoded predictions and actual values to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# Print classification report for detailed metrics
class_report = classification_report(y_true_classes, y_pred_classes)
print(class_report)

with open(os.path.join(result_path, f'{model_name}_classification_report.txt'), 'w') as f:
    f.write(class_report)

# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title(f'{model_name}_Confusion Matrix')


plt.savefig(os.path.join(result_path, f'{model_name}_confusion_matrix.png'))
plt.show()
# Out:
# 171/171 [==============================] - 5s 28ms/step
#               precision    recall  f1-score   support
#
#            0       0.75      0.72      0.73       135
#            1       0.50      0.55      0.53       129
#            2       0.72      0.80      0.76       169
#            3       0.49      0.53      0.51       125
#            4       0.77      0.83      0.80       180
#            5       0.85      0.89      0.87       140
#            6       0.68      0.78      0.73       131
#            7       0.76      0.82      0.79       128
#            8       0.78      0.64      0.70       148
#            9       0.64      0.68      0.66       147
#           10       0.60      0.63      0.61       159
#           11       0.60      0.71      0.65       139
#           12       0.81      0.78      0.80       157
#           13       0.73      0.68      0.71       157
#           14       0.69      0.57      0.62       141
#           15       0.71      0.59      0.65       164
#           16       0.82      0.74      0.78       118
#           17       0.56      0.57      0.56       138
#           18       0.59      0.69      0.64       158
#           19       0.66      0.54      0.59       140
#           20       0.82      0.66      0.73       149
#           21       0.63      0.58      0.60       159
#           22       0.95      0.99      0.97       143
#           23       0.64      0.58      0.61       149
#           24       0.69      0.54      0.61       143
#           25       0.88      0.87      0.87       167
#           26       0.73      0.78      0.75       148
#           27       0.82      0.66      0.73       149
#           28       0.71      0.83      0.76       147
#           29       0.69      0.80      0.74       137
#           30       0.65      0.66      0.65       121
#           31       0.63      0.63      0.63       147
#           32       0.62      0.64      0.63       163
#           33       0.70      0.79      0.74       136
#           34       0.85      0.80      0.82       131
#           35       0.71      0.78      0.74       134
#           36       0.83      0.89      0.86       112
#           37       0.73      0.69      0.71       131
#
#     accuracy                           0.71      5469
#    macro avg       0.71      0.71      0.71      5469
# weighted avg       0.71      0.71      0.71      5469

# %%
# Calculate accuracy using sklearn
accuracy = accuracy_score(y_true_classes, y_pred_classes)
print('Accuracy:', accuracy)

# Calculate precision and recall using sklearn
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
print('Precision:', precision)
print('Recall:', recall)

# Append accuracy to a text file
with open(os.path.join(base_path, 'accuracy.txt'), 'a') as f:
    f.write(f'{model_name}_Accuracy: {accuracy:.2f}%\n')
    f.write(f'{model_name}_Precision: {precision:.2f}%\n')
    f.write(f'{model_name}_Recall: {recall:.2f}%\n')
# Out:
# Accuracy: 0.7074419455110623
# Precision: 0.7105715574036932
# Recall: 0.7074419455110623

# %%
# cnt = 0
# for i in range(len(y_pred_classes)):
#     print('예측 : ', y_pred_classes[i], "실제 :", y_true_classes[i])
#     if y_pred_classes[i] == y_true_classes[i]:
#         cnt += 1
# print('정확도', cnt / len(y_pred_classes) * 100, '%')

# with open(os.path.join(model_path, 'accuracy.txt'), 'w') as f:
#     f.write(f'{model}_Accuracy: {cnt / len(y_pred_classes) * 100:.2f}%\n')
