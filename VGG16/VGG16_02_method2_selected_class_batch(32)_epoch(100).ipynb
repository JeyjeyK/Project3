# %% [markdown]
# https://www.kaggle.com/code/imsparsh/food-classifier-mobilenetv2-resnet50-vgg16

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import random

import tensorflow as tf
from tensorflow.keras import layers as k
from tensorflow.keras.applications import VGG16
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix, classification_report

import json
import pickle
from tqdm import tqdm

import cv2
from google.colab.patches import cv2_imshow

import os
import warnings
warnings.filterwarnings('ignore')

import gc

seed = 42

# %%
image_size = (224, 224, 3)
batch_num = 32
epoch_num = 100

# create_model_name
model = 'VGG16'
numbering = '02'
preprocessing_method ='method2'
class_type = 'selected_class'

# 고정 내역
max_pic_cnt = 1000
top_layer = 'customized_top_layer'

model_name = f'{model}_{numbering}_{preprocessing_method}_{class_type}_batch({batch_num})_epoch({epoch_num})'
print(model_name)
# Out:
# VGG16_02_method2_selected_class_batch(32)_epoch(100)

# %%
# create model folder
base_path = f'/content/drive/MyDrive/project3/image_model/{model}'
if not os.path.exists(base_path):
    os.makedirs(base_path)

model_path = f'/content/drive/MyDrive/project3/image_model/{model}/{model_name}'
if not os.path.exists(model_path):
    os.makedirs(model_path)

# result folder
result_path = f'/content/drive/MyDrive/project3/image_model/{model}/{model_name}/result'
if not os.path.exists(result_path):
    os.makedirs(result_path)

# %% [markdown]
# ### data 준비

# %%
def get_image():
    pkl_dir_path = f'/content/drive/MyDrive/project3/data/traindata/image_to_list/{class_type}_square/{preprocessing_method}.pkl'
    df = pd.read_pickle(pkl_dir_path)

    image_list = np.array([x.reshape(224, 224, 3) for x in df['sq_list']])
    target_list = df['small_class']

    image_list = np.array(image_list).astype(np.uint8)
    target_list = np.array(target_list)

    return image_list, target_list


def prepare_data(test_size=0.2, random_state=42):
    # get_image 함수를 통해서 image / target 가져오기
    image_list, target_list = get_image()

    label_encoder = LabelEncoder()
    encoded_target_list = label_encoder.fit_transform(target_list)

    # Train-Test Split
    X_train, X_test, y_train, y_test = train_test_split(image_list, encoded_target_list, test_size=test_size, random_state=random_state)

    # image_array 정규화
    X_train = X_train / 255.0
    X_test = X_test / 255.0

    num_classes = len(np.unique(target_list))

    # target (one-hot encoding)
    y_train = to_categorical(y_train, num_classes)
    y_test = to_categorical(y_test, num_classes)

    return X_train, X_test, y_train, y_test, target_list, label_encoder

# 나중에 다시 label을 출력하기 위한 코드
def decode_labels(encoded_label, label_encoder):
    return label_encoder.inverse_transform(encoded_label)

# %%
X_train, X_test, y_train, y_test, target_list, label_encoder = prepare_data()
num_classes = len(np.unique(target_list))

print(f"X_train : {X_train.shape}")
print(f"X_test : {X_test.shape}")
print(f"y_train : {y_train.shape}")
print(f"y_test : {y_test.shape}")
print(f'Target count: {num_classes}')
# Out:
# X_train : (21876, 224, 224, 3)
# X_test : (5469, 224, 224, 3)
# y_train : (21876, 38)
# y_test : (5469, 38)
# Target count: 38

# %%
pic_num = 900
decoded_label = decode_labels([np.argmax(y_train[pic_num])], label_encoder)
print(f"Label: {decoded_label[0]}")
print(X_train[pic_num].shape)
cv2_imshow(X_train[pic_num] * 255)
# Out:
# Label: 육개장
# (224, 224, 3)
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# ### 모델 설계

# %%
# Load the VGG16
# model pre-trained -> by imagenet dataset
# without the top layer -> 마지막 결과를 내는 레이어 층에 관한
vgg16 = VGG16(weights='imagenet', input_shape=[224, 224, 3], include_top=False)
vgg16.trainable = False  # Freeze the layers of VGG16

# Define the Customized top layer
model = tf.keras.models.Sequential([
    vgg16,
    tf.keras.layers.GlobalAveragePooling2D(),
    k.Dropout(0.2),
    k.Dense(512, activation='relu'),
    k.BatchNormalization(),
    k.Dropout(0.1),
    k.Dense(256, activation='relu'),
    k.BatchNormalization(),
    k.Dropout(0.1),
    k.Dense(num_classes, activation='softmax')
])

print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 38)                9766
#
# =================================================================
# Total params: 15121510 (57.68 MB)
# Trainable params: 405286 (1.55 MB)
# Non-trainable params: 14716224 (56.14 MB)
# _________________________________________________________________
# None

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint(filepath=os.path.join(model_path, f'{model_name}_best.h5'),
                                   monitor='val_loss', save_best_only=True)


model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=[tf.keras.metrics.CategoricalAccuracy(), tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')]
)

history = model.fit(X_train, y_train, epochs= epoch_num, batch_size= batch_num, validation_split= 0.15,
                    callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/100
# 582/582 [==============================] - 35s 46ms/step - loss: 2.1906 - categorical_accuracy: 0.3898 - precision: 0.6791 - recall: 0.2124 - val_loss: 1.2882 - val_categorical_accuracy: 0.6237 - val_precision: 0.8153 - val_recall: 0.4452
# Epoch 2/100
# 582/582 [==============================] - 19s 33ms/step - loss: 1.6097 - categorical_accuracy: 0.5235 - precision: 0.7137 - recall: 0.3731 - val_loss: 1.1990 - val_categorical_accuracy: 0.6411 - val_precision: 0.7954 - val_recall: 0.5058
# Epoch 3/100
# 582/582 [==============================] - 19s 32ms/step - loss: 1
100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.1214 - categorical_accuracy: 0.6532 - precision: 0.7925 - recall: 0.5411 - val_loss: 0.9555 - val_categorical_accuracy: 0.7087 - val_precision: 0.8313 - val_recall: 0.6094
# Epoch 19/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0951 - categorical_accuracy: 0.6575 - precision: 0.7915 - recall: 0.5496 - val_loss: 0.9937 - val_categorical_accuracy: 0.6947 - val_precision: 0.8211 - val_recall: 0.6012
# Epoch 20/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0708 - categorical_accuracy: 0.6663 - precision: 0.7949 - recall: 0.5564 - val_loss: 0.9355 - val_categorical_accuracy: 0.7221 - val_precision: 0.8480 - val_recall: 0.6085
# Epoch 21/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0724 - categorical_accuracy: 0.6665 - precision: 0.7964 - recall: 0.5623 - val_loss: 0.9315 - val_categorical_accuracy: 0.7105 - val_precision: 0.8230 - val_recall: 0.6219
# Epoch 22/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0664 - categorical_accuracy: 0.6702 - precision: 0.7994 - recall: 0.5657 - val_loss: 0.9369 - val_categorical_accuracy: 0.7133 - val_precision: 0.8244 - val_recall: 0.6252
# Epoch 23/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0442 - categorical_accuracy: 0.6733 - precision: 0.8043 - recall: 0.5681 - val_loss: 0.9256 - val_categorical_accuracy: 0.7154 - val_precision: 0.8385 - val_recall: 0.6219
# Epoch 24/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0431 - categorical_accuracy: 0.6775 - precision: 0.8049 - recall: 0.5730 - val_loss: 0.9217 - val_categorical_accuracy: 0.7148 - val_precision: 0.8398 - val_recall: 0.6292
# Epoch 25/100
# 582/582 [==============================] - 19s 32ms/step - loss: 1.0450 - categorical_accuracy: 0.6742 - precision: 0.8037 - recall: 0.5715 - val_loss: 0.9084 - val_categorical_accuracy: 0.7236 - val_precision: 0.8368 - val_recall: 0.6310
# Epoch 26/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0351 - categorical_accuracy: 0.6777 - precision: 0.8060 - recall: 0.5781 - val_loss: 0.9939 - val_categorical_accuracy: 0.7102 - val_precision: 0.8190 - val_recall: 0.6161
# Epoch 27/100
# 582/582 [==============================] - 19s 32ms/step - loss: 1.0226 - categorical_accuracy: 0.6800 - precision: 0.8073 - recall: 0.5824 - val_loss: 0.8977 - val_categorical_accuracy: 0.7224 - val_precision: 0.8258 - val_recall: 0.6383
# Epoch 28/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0204 - categorical_accuracy: 0.6817 - precision: 0.8037 - recall: 0.5803 - val_loss: 0.9283 - val_categorical_accuracy: 0.7212 - val_precision: 0.8282 - val_recall: 0.6286
# Epoch 29/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.9914 - categorical_accuracy: 0.6900 - precision: 0.8099 - recall: 0.5892 - val_loss: 0.9201 - val_categorical_accuracy: 0.7157 - val_precision: 0.8210 - val_recall: 0.6261
# Epoch 30/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.9997 - categorical_accuracy: 0.6888 - precision: 0.8073 - recall: 0.5915 - val_loss: 0.9135 - val_categorical_accuracy: 0.7218 - val_precision: 0.8288 - val_recall: 0.6298
# Epoch 31/100
# 582/582 [==============================] - 18s 31ms/step - loss: 1.0047 - categorical_accuracy: 0.6877 - precision: 0.8016 - recall: 0.5873 - val_loss: 0.9163 - val_categorical_accuracy: 0.7121 - val_precision: 0.8255 - val_recall: 0.6283
# Epoch 32/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.9948 - categorical_accuracy: 0.6848 - precision: 0.8081 - recall: 0.5876 - val_loss: 0.9082 - val_categorical_accuracy: 0.7249 - val_precision: 0.8214 - val_recall: 0.6350
# Epoch 33/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.
100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.9086 - categorical_accuracy: 0.7122 - precision: 0.8194 - recall: 0.6229 - val_loss: 0.9140 - val_categorical_accuracy: 0.7230 - val_precision: 0.8236 - val_recall: 0.6514
# Epoch 50/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.9161 - categorical_accuracy: 0.7050 - precision: 0.8101 - recall: 0.6184 - val_loss: 0.8885 - val_categorical_accuracy: 0.7288 - val_precision: 0.8249 - val_recall: 0.6545
# Epoch 51/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.9021 - categorical_accuracy: 0.7150 - precision: 0.8191 - recall: 0.6278 - val_loss: 0.8804 - val_categorical_accuracy: 0.7322 - val_precision: 0.8330 - val_recall: 0.6566
# Epoch 52/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.9039 - categorical_accuracy: 0.7158 - precision: 0.8203 - recall: 0.6274 - val_loss: 0.8855 - val_categorical_accuracy: 0.7303 - val_precision: 0.8326 - val_recall: 0.6502
# Epoch 53/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.8942 - categorical_accuracy: 0.7139 - precision: 0.8217 - recall: 0.6289 - val_loss: 0.8845 - val_categorical_accuracy: 0.7328 - val_precision: 0.8232 - val_recall: 0.6612
# Epoch 54/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.9038 - categorical_accuracy: 0.7116 - precision: 0.8199 - recall: 0.6269 - val_loss: 0.8794 - val_categorical_accuracy: 0.7364 - val_precision: 0.8342 - val_recall: 0.6651
# Epoch 55/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.8968 - categorical_accuracy: 0.7159 - precision: 0.8168 - recall: 0.6265 - val_loss: 0.8792 - val_categorical_accuracy: 0.7322 - val_precision: 0.8288 - val_recall: 0.6536
# Epoch 56/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.8800 - categorical_accuracy: 0.7223 - precision: 0.8243 - recall: 0.6371 - val_loss: 0.8957 - val_categorical_accuracy: 0.7291 - val_precision: 0.8206 - val_recall: 0.6536
# Epoch 57/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.8882 - categorical_accuracy: 0.7163 - precision: 0.8177 - recall: 0.6325 - val_loss: 0.8938 - val_categorical_accuracy: 0.7209 - val_precision: 0.8233 - val_recall: 0.6475
# Epoch 58/100
# 582/582 [==============================] - 19s 33ms/step - loss: 0.8841 - categorical_accuracy: 0.7179 - precision: 0.8230 - recall: 0.6366 - val_loss: 0.8664 - val_categorical_accuracy: 0.7380 - val_precision: 0.8315 - val_recall: 0.6706
# Epoch 59/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.8854 - categorical_accuracy: 0.7169 - precision: 0.8187 - recall: 0.6309 - val_loss: 0.8821 - val_categorical_accuracy: 0.7331 - val_precision: 0.8365 - val_recall: 0.6578
# Epoch 60/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.8706 - categorical_accuracy: 0.7243 - precision: 0.8241 - recall: 0.6389 - val_loss: 0.8826 - val_categorical_accuracy: 0.7294 - val_precision: 0.8326 - val_recall: 0.6560
# Epoch 61/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.8659 - categorical_accuracy: 0.7266 - precision: 0.8247 - recall: 0.6439 - val_loss: 0.8819 - val_categorical_accuracy: 0.7380 - val_precision: 0.8306 - val_recall: 0.6603
# Epoch 62/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.8637 - categorical_accuracy: 0.7261 - precision: 0.8248 - recall: 0.6440 - val_loss: 0.8743 - val_categorical_accuracy: 0.7352 - val_precision: 0.8256 - val_recall: 0.6691
# Epoch 63/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.8588 - categorical_accuracy: 0.7301 - precision: 0.8265 - recall: 0.6448 - val_loss: 0.8761 - val_categorical_accuracy: 0.7386 - val_precision: 0.8252 - val_recall: 0.6630
# Epoch 64/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.8595 - categorical_accuracy: 0.7262 - precision: 0.8253 - recall: 0.6446 - val_loss: 0.8760 - val_categorical_accuracy: 0.7364 - val_precision: 0.8280 - val_recall: 0.6642
# Epoch 65/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.8630 - categorical_accuracy: 0.7291 - precision: 0.8213 - recall: 0.6455 - val_loss: 0.8757 - val_categorical_accuracy: 0.7401 - val_precision: 0.8274 - val_recall: 0.6645
# Epoch 66/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.8476 - categorical_accuracy: 0.7298 - precision: 0.8240 - recall: 0.6480 - val_loss: 0.8795 - val_categorical_accuracy: 0.7337 - val_precision: 0.8368 - val_recall: 0.6560
# Epoch 67/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.8607 - categorical_accuracy: 0.7234 - precision: 0.8204 - recall: 0.6435 - val_loss: 0.8785 - val_categorical_accuracy: 0.7358 - val_precision: 0.8203 - val_recall: 0.6621
# Epoch 68/100
# 582/582 [==============================] - 18s 31ms/step - loss: 0.8637 - categorical_accuracy: 0.7286 - precision: 0.8239 - recall: 0.6450 - val_loss: 0.8783 - val_categorical_accuracy: 0.7343 - val_precision: 0.8212 - val_recall: 0.6606

# %%
# model save
model.save(os.path.join(model_path, f'{model_name}.h5'))


# training history save
with open(os.path.join(result_path, f'{model_name}_history.json'), 'w') as f:
    json.dump(history.history, f)

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['categorical_accuracy'], label='Train Accuracy')
plt.plot(history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy By Epochs')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss By Epochs')

plt.suptitle(f'{model_name}')

# save training_plot
plt.savefig(os.path.join(result_path, f'{model_name}_training_plot.png'))
plt.show()

# %%
y_pred = model.predict(X_test)

# Convert one-hot encoded predictions and actual values to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# Print classification report for detailed metrics
class_report = classification_report(y_true_classes, y_pred_classes)
print(class_report)

with open(os.path.join(result_path, f'{model_name}_classification_report.txt'), 'w') as f:
    f.write(class_report)

# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(num_classes), yticklabels=range(num_classes))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title(f'{model_name}_Confusion Matrix')


plt.savefig(os.path.join(result_path, f'{model_name}_confusion_matrix.png'))
plt.show()
# Out:
# 171/171 [==============================] - 5s 29ms/step
#               precision    recall  f1-score   support
#
#            0       0.77      0.76      0.77       135
#            1       0.53      0.60      0.57       129
#            2       0.77      0.73      0.75       169
#            3       0.48      0.59      0.53       125
#            4       0.89      0.76      0.82       180
#            5       0.88      0.89      0.89       140
#            6       0.81      0.72      0.76       131
#            7       0.86      0.88      0.87       128
#            8       0.74      0.70      0.72       148
#            9       0.70      0.76      0.73       147
#           10       0.57      0.58      0.58       159
#           11       0.73      0.76      0.74       139
#           12       0.74      0.81      0.77       157
#           13       0.71      0.72      0.72       157
#           14       0.50      0.78      0.61       141
#           15       0.70      0.59      0.64       164
#           16       0.80      0.69      0.74       118
#           17       0.61      0.36      0.45       138
#           18       0.74      0.70      0.72       158
#           19       0.53      0.59      0.56       140
#           20       0.75      0.73      0.74       149
#           21       0.59      0.65      0.62       159
#           22       0.95      0.99      0.97       143
#           23       0.55      0.64      0.59       149
#           24       0.59      0.69      0.63       143
#           25       0.94      0.90      0.92       167
#           26       0.73      0.66      0.69       148
#           27       0.88      0.58      0.70       149
#           28       0.76      0.81      0.78       147
#           29       0.81      0.69      0.74       137
#           30       0.84      0.67      0.75       121
#           31       0.75      0.67      0.71       147
#           32       0.65      0.58      0.61       163
#           33       0.77      0.81      0.79       136
#           34       0.85      0.81      0.83       131
#           35       0.65      0.77      0.71       134
#           36       0.92      0.82      0.87       112
#           37       0.63      0.82      0.72       131
#
#     accuracy                           0.72      5469
#    macro avg       0.73      0.72      0.72      5469
# weighted avg       0.73      0.72      0.72      5469

# %%
# Calculate accuracy using sklearn
accuracy = accuracy_score(y_true_classes, y_pred_classes)
print('Accuracy:', accuracy)

# Calculate precision and recall using sklearn
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
print('Precision:', precision)
print('Recall:', recall)

# Append accuracy to a text file
with open(os.path.join(base_path, 'accuracy.txt'), 'a') as f:
    f.write(f'{model_name}_Accuracy: {accuracy:.2f}%\n')
    f.write(f'{model_name}_Precision: {precision:.2f}%\n')
    f.write(f'{model_name}_Recall: {recall:.2f}%\n')
# Out:
# Accuracy: 0.7165843847138417
# Precision: 0.727859982530523
# Recall: 0.7165843847138417

# %%
# cnt = 0
# for i in range(len(y_pred_classes)):
#     print('예측 : ', y_pred_classes[i], "실제 :", y_true_classes[i])
#     if y_pred_classes[i] == y_true_classes[i]:
#         cnt += 1
# print('정확도', cnt / len(y_pred_classes) * 100, '%')

# with open(os.path.join(model_path, 'accuracy.txt'), 'w') as f:
#     f.write(f'{model}_Accuracy: {cnt / len(y_pred_classes) * 100:.2f}%\n')
